# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install config
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting config
#   Downloading config-0.5.1-py2.py3-none-any.whl (20 kB)
# Installing collected packages: config
# Successfully installed config-0.5.1

# %%
import os
import shutil
import random

TRAINING_FILES_PATH = "/content/drive/MyDrive/SET_project_1/SER/data/RAV_TESS"
EMODB_ORIGINAL_FOLDER_PATH = "/content/drive/MyDrive/SET_project_1/SER/data/emodb"

class EmoDBPipeline:

    @staticmethod
    def create_tess_folders(path):
        counter = 0
        # 01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised
        # anger W Ärger (Wut)
        # boredom L Langeweile
        # disgust E Ekel
        # anxiety/fear A Angst
        # happiness F Freude
        # sadness T Trauer
        # n = neutral

        label_conversion = {'01': 'N',
                            '03': 'F',
                            '04': 'T',
                            '05': 'W',
                            '06': 'A'
                            '07': 'E',
                            '09': 'L'} #Boredom

        for subdir, dirs, files in os.walk(path):
            for filename in files:
                destination_path = TRAINING_FILES_PATH + '/Actor_28//'
                old_file_path = os.path.join(os.path.abspath(subdir), filename)

                # Separate base from extension
                base, extension = os.path.splitext(filename)

                for key, value in label_conversion.items():
                    if base[-2] == value:
                      print(base)
                      random_list = random.sample(range(10, 99), 7)
                      file_name = '-'.join([str(i) for i in random_list])
                      file_name_with_correct_emotion = file_name[:6] + key + file_name[8:] + extension
                      new_file_path = destination_path + file_name_with_correct_emotion
                      shutil.copy(old_file_path, new_file_path)
                      counter +=1

        print(f"Finished, file count: {counter}")

if __name__ == '__main__':
    EmoDBPipeline.create_tess_folders(EMODB_ORIGINAL_FOLDER_PATH)
# Out:
# 03a01Fa
# 03a04Fd
# 03a02Fc
# 03a05Fc
# 03a04Wc
# 03a05Wb
# 03a05Wa
# 03b09Tc
# 14a04Ed
# 15b01Ec
# 14a02Ab
# 09a07Wb
# 16b10Wb
# 16a07Lb
# 13b10La
# 12b01Ta
# 11a02Ld
# 13b09Fb
# 14a05Aa
# 09b03Fa
# 13a07Fd
# 13a04Ac
# 13a07Na
# 10b03La
# 14a04Aa
# 10a04Wb
# 08a05Fe
# 15b10Nb
# 03a01Nc
# 13b10Ec
# 11a07Wc
# 11a05Td
# 11a01Ld
# 08a02Fe
# 14b03Ed
# 14a01Na
# 16a07Fb
# 15a07Ld
# 14a01Wc
# 03a04Nc
# 14a04Lb
# 15b03Wb
# 16b01Tb
# 03b02Wb
# 14a07Fd
# 08b02Nb
# 11a05Wd
# 16a01Wb
# 10b01Aa
# 12b09Wc
# 13b09Fc
# 12a01Lb
# 03b10Wb
# 13a07Lb
# 09b09Nd
# 11b09Na
# 13a02Nc
# 15a05Lb
# 13a01Wb
# 13a05Wc
# 03b09Nc
# 03a07Wc
# 11a01Ab
# 10a02Ab
# 16b03Fa
# 16b03Nb
# 16b10Eb
# 12b02Wd
# 15a01Nb
# 11b03Fc
# 03b10Ab
# 12a02Nb
# 10b10Fc
# 13b09Wa
# 11b02Na
# 12a02Ec
# 08a02Tb
# 08a07Wc
# 13b02Wa
# 08b09Wa
# 16b02Wb
# 14a01Ac
# 13a01Ea
# 08a01Wc
# 15a04Fd
# 13a01Ec
# 16a04Ab
# 12b09Ac
# 15b10Ac
# 16a05Wb
# 11b03Nb
# 11b01Fc
# 11a05Fc
# 15b10Wa
# 03b01Fa
# 10b09Wb
# 11a05Na
# 16a02Ea
# 16b01La
# 16b10Lb
# 08b01Wa
# 10b10Lc
# 10a02Lb
# 15a01Fb
# 14a04Tb
# 11a01Wc
# 16a07Td
# 15a05Eb
# 10a07Wb
# 11b01Lb
# 14a04Wc
# 14b10Eb
# 10b09Lb
# 13b03Ac
# 14b01Fc
# 11a01Aa
# 09b02Tb
# 15a01La
# 12b02Wb
# 09b02Wc
# 15b02Wa
# 03a05Nd
# 08b03Lc
# 12a05Lb
# 15a07Nc
# 16a05Fc
# 15b03Aa
# 14b09Td
# 13a05Lc
# 13a02Ta
# 12b02Ea
# 16b02Eb
# 11a07Ld
# 11b02Td
# 13b10Wa
# 13a07Tc
# 14b09Ac
# 11a02Tc
# 10a04Fd
# 14b10Wc
# 15a05Wa
# 09a01Wb
# 09b09Ea
# 16a02Ec
# 08a02Ab
# 10b01Lb
# 08a02Wc
# 08b03Nb
# 10a05Aa
# 14a05Wa
# 16b01Aa
# 08b09Tb
# 11b09Fd
# 15a04Ab
# 08a05Wa
# 03b03Wc
# 16b03Ta
# 13b03Lb
# 16a02Nb
# 09b03Nb
# 09a02Wb
# 08a05Lc
# 10a02Wa
# 15b09Ac
# 09b10Wa
# 16a05Ea
# 03b03Tc
# 15b02Nd
# 13b03Td
# 12a01Wc
# 10b03Wb
# 08b09Lc
# 09a05Ed
# 08a01Na
# 14a04Wb
# 13a04Lb
# 14b10Nb
# 14a02Wc
# 15b09La
# 14b03Ad
# 08b10Wa
# 03a04Lc
# 12a07Wa
# 15b01Na
# 03b01Lb
# 08a07Tb
# 16a04Ea
# 16a02Wb
# 08b02Tc
# 03b10Nc
# 03a02Wb
# 13b02Fb
# 09a01Fa
# 03b01Wa
# 14b02Aa
# 15a02La
# 14a05Fb
# 11b02Wb
# 12a05Ab
# 16b09La
# 16a02Tc
# 08a04La
# 03a04Ad
# 14a02Fd
# 03a05Tc
# 09b03Ed
# 13a01Fd
# 15a04Wa
# 11b01Wd
# 11a04Ac
# 14b01Ac
# 09a05Wb
# 13a05Nb
# 15a02Ac
# 12b10Wa
# 14b09Ea
# 11b03Wa
# 13b10Nc
# 03a01Wa
# 08a04Ff
# 13a02Fa
# 08b10Tc
# 08b03Tc
# 12a07Ac
# 14b01Wc
# 10b02Wb
# 09a07Eb
# 16b09Lb
# 14b09Fc
# 10a07Ad
# 16b09Wb
# 03b10Na
# 14b01Eb
# 13b03Na
# 16b10Aa
# 10b02Na
# 16b03La
# 11b01Eb
# 10a02Fa
# 09b03Lb
# 14a05Tc
# 03b02Na
# 16a01Ec
# 11b10Nc
# 12b10Ld
# 12a01Nb
# 08b02La
# 03a02Wc
# 14a05Na
# 14a07Tc
# 09b02Na
# 09b01Ea
# 16b10Tb
# 12b02Wa
# 09a07Na
# 14a02Ea
# 03b10Ec
# 12b01Wa
# 16a04Wc
# 03a07La
# 15b01Wc
# 14a02La
# 12b03Ta
# 08a07Fd
# 12a02Wa
# 09b10Aa
# 14a07Wc
# 13a02Ec
# 15b09Nb
# 15a01Wa
# 15b01Lb
# 14a07Na
# 10b03Tb
# 16a02Lb
# 10a07Ta
# 16a07Wa
# 09a05Wc
# 14b09Lb
# 13b01Wa
# 11b03Wb
# 16a04Tc
# 09a05Lc
# 10b01Fa
# 15a05Na
# 09a07Wd
# 16a07La
# 03a02Nc
# 12a05Nd
# 15a04Ac
# 14a07Ld
# 11b03Lc
# 10a01Ac
# 16b10Wa
# 14a01Wa
# 16a07Nb
# 08b01Aa
# 08b10Aa
# 16a01Fc
# 15b02Aa
# 11b09Td
# 09a04La
# 16a07Fa
# 08b09Fd
# 11b09Ld
# 09a01Nb
# 08a02Na
# 11b03Td
# 09a04Wa
# 14b10Tc
# 10b10Wa
# 16b02Lb
# 16b09Eb
# 13b03Ed
# 13b10Wc
# 09b03Ta
# 11b10Td
# 14b02Na
# 16b01Wb
# 08b09Wc
# 16a01Tb
# 11b10Wa
# 11b10Ld
# 12a01Fb
# 08a07Na
# 15b03Tc
# 14b10Lb
# 14a05Fa
# 14a07Lc
# 08a05Nb
# 16b03Wb
# 13a04Wc
# 08b10Fd
# 12b03La
# 14b03Lb
# 16a04Nc
# 12a02Ac
# 11a07Ta
# 09a04Nb
# 13b10Fa
# 08b09Ab
# 08b01Lb
# 08a01Ab
# 14b01Na
# 08a01Wa
# 03b02Tb
# 15a02Na
# 11a07Ac
# 11a04Nd
# 03a07Nc
# 13b09Ec
# 09a05Tb
# 11b02Ab
# 09b03Wb
# 09a07Ta
# 16a01Nc
# 13b01Ab
# 14b01Fa
# 10a05Wb
# 14a05Ac
# 12b10Ac
# 14b02Wd
# 08b01Na
# 08b01Fd
# 08a07La
# 12a07La
# 08a05Ta
# 13a02Wa
# 03b01Wc
# 08b02Ff
# 10a07La
# 10b09Ad
# 13a05Tc
# 08b09Nb
# 14b10Ad
# 16a05La
# 13b01Ld
# 08a07Ta
# 15b03Lc
# 10a04Nb
# Finished, file count: 535
